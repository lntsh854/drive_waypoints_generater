# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %%
csv_dir = '/home/ivslab/Desktop/Waypoints_Vision_CSV/tmp.csv'
df_pred = pd.read_csv(csv_dir)
fig = plt.figure(figsize=(12,8))



csv_dir = '/home/ivslab/Desktop/NCTU_ROUND/nctu_round.csv'
df = pd.read_csv(csv_dir)

# marker_style = {'filled_markers':'o',
#  'fillstyles ':'none'}
plt.scatter(df['x'],df['y'],s=[200 for i in range(len(df['x']))], c='r', alpha=0.01,facecolors='none',marker='o')
plt.scatter(df_pred['X'],df_pred['Y'],s=[200 for i in range(len(df['x']))], c='g', alpha=0.1,facecolors='none',marker='o')
plt.show()

# %%
df_pred
# Out:
#      Unnamed: 0           X           Y
# 0             0  254.635239    9.422195
# 1             1  256.670044    8.741813
# 2             2  258.711179    7.959762
# 3             3  260.714003    7.820536
# 4             4  262.749070    7.185673
# 5             0  259.910341    7.369955
# 6             1  261.697731    5.811918
# 7             2  263.512290    4.453654
# 8             3  265.319545    3.040491
# 9             4  266.121451    1.648098
# 10            0  264.216845    3.588841
# 11            1  265.448394    1.430494
# 12            2  266.739120   -0.588267
# 13            3  267.997385   -2.681377
# 14            4  268.326932   -4.405820
# 15            5  269.544987   -6.592366
# 16            6  269.940966   -8.165722
# 17            7  271.418806   -9.754663
# 18            8  271.960402  -10.998759
# 19            9  272.310436  -12.681639
# 20            0  266.439051   -0.471001
# 21            1  268.620290   -2.582742
# ...

# %%
df
# Out:
#             x       y       z     yaw  velocity  change_flag
# 0     12.5658  1.7363  0.5129  0.0447    0.0000            0
# 1     13.6646  1.7875  0.5645  0.0318    4.2596            0
# 2     14.8768  1.8835  0.5405  0.0200    8.0416            0
# 3     15.9982  1.9612  0.5640  0.0282    7.8865            0
# 4     16.9966  2.0631  0.5593  0.0408    6.4507            0
# 5     18.0499  2.1139  0.5790  0.0397    6.9886            0
# 6     19.0745  2.2183  0.6152  0.0311    6.7887            0
# 7     20.1114  2.3116  0.6148  0.0226    5.6120            0
# 8     21.2126  2.3318  0.6449  0.0103    5.7699            0
# 9     22.3988  2.4084  0.6542 -0.0027    8.3735            0
# 10    23.5385  2.4183  0.6413 -0.0134    6.3926            0
# 11    24.5971  2.4729  0.6692 -0.0225    7.8875            0
# 12    25.7076  2.4779  0.7060 -0.0217    8.0236            0
# 13    26.7272  2.5098  0.6915 -0.0103    5.7634            0
# ...
